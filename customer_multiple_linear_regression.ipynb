# %%
# Import dependencies
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# from sklearn.compose import make_column_transformer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import dataset
df = pd.read_csv('Resources/customer_data.csv')
df.head()
# Out:
#    id marital_status gender  total_children            education member_card  \
# 0   0              M      F             1.0  Partial High School      Normal
# 1   1              M      M             0.0     Bachelors Degree      Silver
# 2   2              S      F             4.0  Partial High School      Normal
# 3   3              M      F             2.0   High School Degree      Bronze
# 4   4              M      M             0.0  Partial High School      Bronze
#
#        occupation houseowner  avg_cars_at_home_approx  avg_yearly_income  \
# 0  Skilled Manual          Y                      1.0              10000
# 1    Professional          Y                      4.0              50000
# 2          Manual          N                      1.0              10000
# 3          Manual          Y                      2.0              30000
# 4  Skilled Manual          N                      2.0              30000
#
#    num_children_at_home store_city store_state          media_type    cost  \
# 0                   1.0      Salem          OR  Daily Paper, Radio  126.62
# 1                   0.0      Salem          OR  Daily Paper, Radio   59.86
# 2                   0.0      Salem          OR  Daily Paper, Radio   84.16
# 3                   2.0      Salem          OR     In-Store Coupon   95.78
# 4                   0.0      Salem          OR               Radio   50.79
#
#           promotion_name  store_sales_in_millions
# 0           Bag Stuffers                     7.36
# 1  Cash Register Lottery                     5.52
# 2    High Roller Savings                     3.68
# 3  Cash Register Lottery                     3.68
# 4       Double Down Sale                     4.08

# %%
# Check data frame shape
shape = df.shape
print(f"Store dataset including {shape[0]} rows and {shape[1]} cloumns.")
# Out:
# Store dataset including 38892 rows and 17 cloumns.

# %%
# Check data frame columns
df.columns
# Out:
# Index(['id', 'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at_home_approx',
#        'avg_yearly_income', 'num_children_at_home', 'store_city',
#        'store_state', 'media_type', 'cost', 'promotion_name',
#        'store_sales_in_millions'],
#       dtype='object')

# %%
# Generate a categorical variable list
cat = df.dtypes[df.dtypes == 'object'].index.tolist()
cat
# Out:
# ['marital_status',
#  'gender',
#  'education',
#  'member_card',
#  'occupation',
#  'houseowner',
#  'store_city',
#  'store_state',
#  'media_type',
#  'promotion_name']

# %%
# Count the number of categorical variables.
print(f"There are {len(cat)} categorical variables in whole data frame.")
# Out:
# There are 10 categorical variables in whole data frame.

# %%
# Generate a numerical variable list
int_float = df.dtypes[(df.dtypes == 'int64') | (df.dtypes == 'float64')].index.tolist()
int_float
# Out:
# ['id',
#  'total_children',
#  'avg_cars_at_home_approx',
#  'avg_yearly_income',
#  'num_children_at_home',
#  'cost',
#  'store_sales_in_millions']

# %%
# Count the number of numerical variables.
print(f"There are {len(int_float)} numerical variables in whole data frame.")
# Out:
# There are 7 numerical variables in whole data frame.

# %%
# Select columns from customer table.
customer_cols = ['marital_status', 'gender', 'total_children', 'education',\
       'member_card', 'occupation', 'houseowner', 'avg_cars_at_home_approx',\
       'avg_yearly_income', 'num_children_at_home', 'store_city',\
       'store_state', 'media_type', 'cost', 'promotion_name',
       'store_sales_in_millions']

# %%
# Display customer data frame.
customer_df = df[customer_cols]
print(f"Shape: {df.shape}")
customer_df.head()
# Out:
# Shape: (38892, 17)
#   marital_status gender  total_children            education member_card  \
# 0              M      F             1.0  Partial High School      Normal
# 1              M      M             0.0     Bachelors Degree      Silver
# 2              S      F             4.0  Partial High School      Normal
# 3              M      F             2.0   High School Degree      Bronze
# 4              M      M             0.0  Partial High School      Bronze
#
#        occupation houseowner  avg_cars_at_home_approx  avg_yearly_income  \
# 0  Skilled Manual          Y                      1.0              10000
# 1    Professional          Y                      4.0              50000
# 2          Manual          N                      1.0              10000
# 3          Manual          Y                      2.0              30000
# 4  Skilled Manual          N                      2.0              30000
#
#    num_children_at_home store_city store_state          media_type    cost  \
# 0                   1.0      Salem          OR  Daily Paper, Radio  126.62
# 1                   0.0      Salem          OR  Daily Paper, Radio   59.86
# 2                   0.0      Salem          OR  Daily Paper, Radio   84.16
# 3                   2.0      Salem          OR     In-Store Coupon   95.78
# 4                   0.0      Salem          OR               Radio   50.79
#
#           promotion_name  store_sales_in_millions
# 0           Bag Stuffers                     7.36
# 1  Cash Register Lottery                     5.52
# 2    High Roller Savings                     3.68
# 3  Cash Register Lottery                     3.68
# 4       Double Down Sale                     4.08

# %%
# Use LabelEncoder to encode categorical columns.
label_encoder = LabelEncoder()

# selected_store_df.loc[:,selected_cat] = label_encoder.fit_transform(selected_store_df.loc[:,selected_cat])
for var in cat:
    customer_df[var] = label_encoder.fit_transform(customer_df[var])

customer_df
# Out:
# /var/folders/fx/3xjkq6_j0w52ql5m_lv0vsbr0000gn/T/ipykernel_7573/2253611990.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_df[var] = label_encoder.fit_transform(customer_df[var])
#        marital_status  gender  total_children  education  member_card  \
# 0                   0       0             1.0          4            2
# 1                   0       1             0.0          0            3
# 2                   1       0             4.0          4            2
# 3                   0       0             2.0          2            0
# 4                   0       1             0.0          4            0
# ...               ...     ...             ...        ...          ...
# 38887               1       0             2.0          2            0
# 38888               1       0             1.0          4            0
# 38889               0       0             1.0          4            2
# 38890               1       0             2.0          2            0
# 38891               0       1             1.0          2            0
#
#        occupation  houseowner  avg_cars_at_home_approx  avg_yearly_income  \
# 0               4           1                      1.0              10000
# 1               3           1                      4.0              50000
# 2               2           0                      1.0              10000
# 3               2           1                      2.0              30000
# 4               4           0                      2.0              30000
# ...           ...         ...                      ...                ...
# 38887           3           1                      3.0             130000
# 38888           4           0                      2.0              50000
# 38889           4           1                      1.0              10000
# 38890           4           0                      2.0              30000
# 38891           2           1                      3.0              30000
#
#        num_children_at_home  store_city  store_state  media_type    cost  \
# 0                       1.0           5            1           3  126.62
# 1                       0.0           5            1           3   59.86
# 2                       0.0           5            1           3   84.16
# 3                       2.0           5            1           5   95.78
# 4                       0.0           5            1           7   50.79
# ...                     ...         ...          ...         ...     ...
# 38887                   0.0           6            0           1  127.19
# 38888                   0.0           6            0          10   78.45
# 38889                   1.0           6            0           5   95.25
# 38890                   0.0           6            0           9   69.42
# 38891                   0.0           6            0          11   67.51
#
#        promotion_name  store_sales_in_millions
# 0                   0                     7.36
# 1                   6                     5.52
# 2                  18                     3.68
# 3                   6                     3.68
# 4                  11                     4.08
# ...               ...                      ...
# 38887              17                     0.99
# 38888              45                     1.21
# 38889              48                     2.76
# 38890              24                     1.60
# 38891              47                     5.52
#
# [38892 rows x 16 columns]

# %%
# Check new data frame infomation.
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38892 entries, 0 to 38891
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   marital_status           38892 non-null  int64
#  1   gender                   38892 non-null  int64
#  2   total_children           38892 non-null  float64
#  3   education                38892 non-null  int64
#  4   member_card              38892 non-null  int64
#  5   occupation               38892 non-null  int64
#  6   houseowner               38892 non-null  int64
#  7   avg_cars_at_home_approx  38892 non-null  float64
#  8   avg_yearly_income        38892 non-null  int64
#  9   num_children_at_home     38892 non-null  float64
#  10  store_city               38892 non-null  int64
#  11  store_state              38892 non-null  int64
#  12  media_type               38892 non-null  int64
#  13  cost                     38892 non-null  float64
#  14  promotion_name           38892 non-null  int64
#  15  store_sales_in_millions  38892 non-null  float64
# dtypes: float64(5), int64(11)
# memory usage: 4.7 MB

# %%
# Check unique values of each column.
customer_df.nunique()
# Out:
# marital_status                2
# gender                        2
# total_children                6
# education                     5
# member_card                   4
# occupation                    5
# houseowner                    2
# avg_cars_at_home_approx       5
# avg_yearly_income             8
# num_children_at_home          6
# store_city                   10
# store_state                   3
# media_type                   13
# cost                        214
# promotion_name               49
# store_sales_in_millions    1011
# dtype: int64

# %%
# Export dataset as a new csv file.
customer_df.to_csv('Resources/customer_label_encoded.csv')

# %% [markdown]
# ### Cost as target

# %%
# Split preprocessed data into our features and target arrays
y = customer_df['cost'].values
X = customer_df.drop(columns='cost').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Shapes of splitted data
print(f"X_train: {X_train.shape};")
print(f"X_test: {X_test.shape};")
print(f"y_train: {y_train.shape};")
print(f"y_test: {y_test.shape};")
# Out:
# X_train: (29169, 15);
# X_test: (9723, 15);
# y_train: (29169,);
# y_test: (9723,);

# %%
# Fit the model
mlg = LinearRegression()
mlg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the result
y_pred = mlg.predict(X_test)
y_pred
# Out:
# array([101.75680088,  99.61796074,  98.83926354, ...,  95.6034649 ,
#         96.79343709, 101.49705231])

# %%
# Evaluate the model
accuracy = r2_score(y_test, y_pred) 
print(f"Accuracy of multiple linear regression is {accuracy:.2f}.")
# Out:
# Accuracy of multiple linear regression is 0.01.

# %%
# Plot the result 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
sns.regplot(x=y_test,y=y_pred,ci=None,color ='b')
# Out:
# <AxesSubplot:xlabel='Actual', ylabel='Predicted'>

# %% [markdown]
# ### Store sales as target

# %%
# Split preprocessed data into our features and target arrays
y = customer_df['store_sales_in_millions'].values
X = customer_df.drop(columns='store_sales_in_millions').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Shapes of splitted data
print(f"X_train: {X_train.shape};")
print(f"X_test: {X_test.shape};")
print(f"y_train: {y_train.shape};")
print(f"y_test: {y_test.shape};")
# Out:
# X_train: (29169, 15);
# X_test: (9723, 15);
# y_train: (29169,);
# y_test: (9723,);

# %%
# Fit the model
mlg = LinearRegression()
mlg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the result
y_pred = mlg.predict(X_test)
y_pred
# Out:
# array([6.12846459, 6.7023801 , 6.59565682, ..., 6.81087912, 6.72047357,
#        6.70410856])

# %%
# Evaluate the model
accuracy = r2_score(y_test, y_pred) 
print(f"Accuracy of multiple linear regression is {accuracy:.2f}.")
# Out:
# Accuracy of multiple linear regression is 0.01.

# %%
# Plot the result 
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
sns.regplot(x=y_test,y=y_pred,ci=None,color ='g')
# Out:
# <AxesSubplot:xlabel='Actual', ylabel='Predicted'>

# %% [markdown]
# ## Heatmap

# %%
# Calculating a correalation matrix
matrix = customer_df.corr(
    method = 'pearson',     # The method of correlation
    min_periods =1          # Min number of observations required
).round(2)
print(matrix)
# Out:
#                          marital_status  gender  total_children  education  \
# marital_status                     1.00    0.02           -0.04       0.01
# gender                             0.02    1.00           -0.01      -0.00
# total_children                    -0.04   -0.01            1.00      -0.00
# education                          0.01   -0.00           -0.00       1.00
# member_card                       -0.05    0.01            0.03       0.32
# occupation                        -0.03   -0.01            0.01       0.14
# houseowner                        -0.28   -0.02            0.02      -0.03
# avg_cars_at_home_approx           -0.07    0.01            0.10      -0.34
# avg_yearly_income                 -0.02   -0.01           -0.00      -0.40
# num_children_at_home              -0.64    0.00            0.39       0.01
# store_city                        -0.05   -0.03            0.06       0.00
# store_state                       -0.02   -0.04            0.02       0.01
# media_type                         0.00   -0.01           -0.01       0.00
# cost                               0.01   -0.01           -0.00      -0.01
# promotion_name                    -0.01   -0.00           -0.01      -0.02
# store_sales_in_millions           -0.01    0.00            0.08       0.00
#
#                          member_card  occupation  houseowner  \
# marital_status                 -0.05       -0.03       -0.28
# gender                          0.01       -0.01       -0.02
# total_children                  0.03        0.01        0.02
# education                       0.32        0.14       -0.03
# member_card                     1.00        0.07        0.03
# occupation                      0.07        1.00        0.03
# houseowner                      0.03        0.03        1.00
# avg_cars_at_home_approx        -0.30       -0.09        0.06
# avg_yearly_income              -0.19       -0.19        0.16
# num_children_at_home            0.14        0.03        0.21
# store_city                     -0.03        0.03        0.01
# store_state                    -0.02        0.00        0.00
# media_type                     -0.01        0.00        0.01
# cost                           -0.02       -0.02        0.01
# promotion_name                  0.01       -0.01        0.01
# store_sales_in_millions        -0.01        0.01        0.00
#
#                          avg_cars_at_home_approx  avg_yearly_income  \
# marital_status                             -0.07              -0.02
# gender                                      0.01              -0.01
# total_children                              0.10              -0.00
# education                                  -0.34              -0.40
# member_card                                -0.30              -0.19
# occupation                                 -0.09              -0.19
# houseowner                                  0.06               0.16
# avg_cars_at_home_approx                     1.00               0.33
# avg_yearly_income                           0.33               1.00
# num_children_at_home                        0.14               0.02
# store_city                                 -0.01               0.00
# store_state                                -0.00              -0.02
# media_type                                  0.02               0.00
# cost                                        0.03              -0.00
# promotion_name                             -0.01              -0.01
# store_sales_in_millions                    -0.00              -0.00
#
#                          num_children_at_home  store_city  store_state  \
# marital_status                          -0.64       -0.05        -0.02
# gender                                   0.00       -0.03        -0.04
# total_children                           0.39        0.06         0.02
# education                                0.01        0.00         0.01
# member_card                              0.14       -0.03        -0.02
# occupation                               0.03        0.03         0.00
# houseowner                               0.21        0.01         0.00
# avg_cars_at_home_approx                  0.14       -0.01        -0.00
# avg_yearly_income                        0.02        0.00        -0.02
# num_children_at_home                     1.00        0.06         0.02
# store_city                               0.06        1.00         0.64
# store_state                              0.02        0.64         1.00
# media_type                              -0.01        0.13         0.13
# cost                                     0.00       -0.04        -0.02
# promotion_name                           0.01        0.01         0.06
# store_sales_in_millions                  0.02        0.02         0.01
#
#                          media_type  cost  promotion_name  \
# marital_status                 0.00  0.01           -0.01
# gender                        -0.01 -0.01           -0.00
# total_children                -0.01 -0.00           -0.01
# education                      0.00 -0.01           -0.02
# member_card                   -0.01 -0.02            0.01
# occupation                     0.00 -0.02           -0.01
# houseowner                     0.01  0.01            0.01
# avg_cars_at_home_approx        0.02  0.03           -0.01
# avg_yearly_income              0.00 -0.00           -0.01
# num_children_at_home          -0.01  0.00            0.01
# store_city                     0.13 -0.04            0.01
# store_state                    0.13 -0.02            0.06
# media_type                     1.00 -0.05           -0.07
# cost                          -0.05  1.00            0.07
# promotion_name                -0.07  0.07            1.00
# store_sales_in_millions       -0.00 -0.00            0.01
#
#                          store_sales_in_millions
# marital_status                             -0.01
# gender                                      0.00
# total_children                              0.08
# education                                   0.00
# member_card                                -0.01
# occupation                                  0.01
# houseowner                                  0.00
# avg_cars_at_home_approx                    -0.00
# avg_yearly_income                          -0.00
# num_children_at_home                        0.02
# store_city                                  0.02
# store_state                                 0.01
# media_type                                 -0.00
# cost                                       -0.00
# promotion_name                              0.01
# store_sales_in_millions                     1.00

# %%
# Visualizing a Pandas correlation matrix using seaborn
plt.figure(figsize = (15,8))
# sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(matrix, annot=True, vmax=1, vmin=-1, center=0, cmap='vlag')
plt.show()

# %%
# Show only the bottom half of correclation matrix
plt.figure(figsize=(15, 8))
mask = np.triu(np.ones_like(matrix, dtype=bool))
sns.heatmap(matrix, annot=True, vmax=1, vmin=-1, center=0, cmap='vlag', mask=mask)
plt.show()

# %%
# Select only strong correlactions in matrix
strong_matrix = matrix.unstack()
strong_matrix = strong_matrix[abs(strong_matrix) >= 0.7]
print(strong_matrix)
# Out:
# marital_status           marital_status             1.0
# gender                   gender                     1.0
# total_children           total_children             1.0
# education                education                  1.0
# member_card              member_card                1.0
# occupation               occupation                 1.0
# houseowner               houseowner                 1.0
# avg_cars_at_home_approx  avg_cars_at_home_approx    1.0
# avg_yearly_income        avg_yearly_income          1.0
# num_children_at_home     num_children_at_home       1.0
# store_city               store_city                 1.0
# store_state              store_state                1.0
# media_type               media_type                 1.0
# cost                     cost                       1.0
# promotion_name           promotion_name             1.0
# store_sales_in_millions  store_sales_in_millions    1.0
# dtype: float64
